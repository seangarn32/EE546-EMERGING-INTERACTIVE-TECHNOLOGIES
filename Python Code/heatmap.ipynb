# %%
import matplotlib
import serial
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import threading
import queue
import time
import matplotlib.animation as animation
import csv
import os

# %% [markdown]
# Heatmap Data Recording

# %%
# CONFIGURATION
SERIAL_PORT = '/dev/tty.usbserial-0001'  # Change to match your device
BAUD_RATE = 250000
DURATION_SECONDS = 30                    # Duration to collect data

# Setup serial
ser = serial.Serial(SERIAL_PORT, BAUD_RATE, timeout=0.05)
matplotlib.use('TkAgg')

# Heatmap setup
cmap = mcolors.LinearSegmentedColormap.from_list("custom", ["red", "yellow", "green"])
fig, ax = plt.subplots()
matrix = np.zeros((5, 3))
heatmap = ax.imshow(matrix, cmap=cmap, vmin=0, vmax=2.8)
plt.colorbar(heatmap, label="Voltage (V)")
ax.set_xticks(np.arange(3))
ax.set_yticks(np.arange(5))
ax.set_xticklabels(["CH1", "CH2", "CH3"])
ax.set_yticklabels(["CH1", "CH2", "CH3", "CH4", "CH5"])
plt.title("5x3 Matrix Voltage Visualization")

cell_texts = [[ax.text(j, i, "", ha="center", va="center", color="black", fontsize=12)
               for j in range(3)] for i in range(5)]

# CSV Setup
CSV_FILE = "/Users/garn195/EE546/EE546-EMERGING-INTERACTIVE-TECHNOLOGIES/Python Code/running_data/neutral_6"
with open(CSV_FILE, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['timestamp'] + [f'R{r}C{c}' for r in range(5) for c in range(3)])

# Data structures
data_queue = queue.Queue()
recording_active = True

def update_plot(frame):
    if not data_queue.empty():
        new_matrix = data_queue.get()
        heatmap.set_data(new_matrix)
        for i in range(5):
            for j in range(3):
                cell_texts[i][j].set_text(f"{new_matrix[i][j]:.2f}")
    return [heatmap] + [text for row in cell_texts for text in row]

def read_arduino_data():
    global recording_active
    while recording_active:
        try:
            line = ser.readline().decode('utf-8', errors='ignore').strip()
            if "Matrix updated:" in line:
                new_matrix = np.zeros((5, 3))
                for i in range(5):
                    row_data = ser.readline().decode('utf-8', errors='ignore').strip().split(",")
                    if len(row_data) == 3:
                        new_matrix[i] = [float(val) for val in row_data]

                timestamp = time.time()
                flat_data = new_matrix.flatten()
                with open(CSV_FILE, mode='a', newline='') as file:
                    writer = csv.writer(file)
                    writer.writerow([timestamp] + list(flat_data))

                data_queue.put(new_matrix)
        except Exception as e:
            print(f"Serial read error: {e}")

def stop_recording_after_delay():
    global recording_active
    time.sleep(DURATION_SECONDS)
    print(f"\nRecording stopped after {DURATION_SECONDS} seconds.")
    recording_active = False
    ser.close()

# Start threads
threading.Thread(target=read_arduino_data, daemon=True).start()
threading.Thread(target=stop_recording_after_delay, daemon=True).start()

# Run animation
ani = animation.FuncAnimation(fig, update_plot, interval=50, blit=True)
plt.show()
# Out:
# /var/folders/b5/cbnlm0vn1j54xy3c75jt4gwc0000gn/T/ipykernel_58653/1422150895.py:78: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = animation.FuncAnimation(fig, update_plot, interval=50, blit=True)
# Serial read error: could not convert string to float: '2.7.8498'
#
# Recording stopped after 30 seconds.
# Serial read error: read failed: [Errno 9] Bad file descriptor

# %% [markdown]
# Graphing

# %%
matplotlib.use('TkAgg')

SERIAL_PORT = '/dev/cu.usbserial-0001'
# SERIAL_PORT = 'dev/tty.'
BAUD_RATE = 250000
ser = serial.Serial(SERIAL_PORT, BAUD_RATE, timeout=0.05)

# Heatmap color map (optional)
# cmap = mcolors.LinearSegmentedColormap.from_list("custom", ["red", "yellow", "green"])

# Create figure and axis for plots
fig, (ax_graph) = plt.subplots(1, 1, figsize=(10, 6))

# ---- HEATMAP SETUP (COMMENTED OUT) ----
# matrix = np.zeros((5, 3))
# heatmap = ax_heatmap.imshow(matrix, cmap=cmap, vmin=0, vmax=3.3)
# cbar = plt.colorbar(heatmap, ax=ax_heatmap, label="Voltage (V)")
# ax_heatmap.set_xticks(np.arange(3))
# ax_heatmap.set_yticks(np.arange(5))
# ax_heatmap.set_xticklabels(["CH1", "CH2", "CH3"])
# ax_heatmap.set_yticklabels(["CH1", "CH2", "CH3", "CH4", "CH5"])
# ax_heatmap.set_title("5x3 Matrix Voltage Visualization")
# cell_texts = [[ax_heatmap.text(j, i, "", ha="center", va="center", color="black", fontsize=12)
#                for j in range(3)] for i in range(5)]

# Setup for real-time line plot
max_history = 200
time_series_data = [[[] for _ in range(3)] for _ in range(5)]  # 5x3 grid
x_vals = list(range(-max_history + 1, 1))

# Create line objects for each cell
lines = [[ax_graph.plot(x_vals, [0]*max_history, label=f"({i},{j})")[0] for j in range(3)] for i in range(5)]

# Configure the graph
ax_graph.set_ylim(0, 3.5)
ax_graph.set_xlim(-max_history + 1, 0)
ax_graph.set_title("Real-time Voltage Trends")
ax_graph.set_xlabel("Time (frames)")
ax_graph.set_ylabel("Voltage (V)")
ax_graph.legend(loc="upper right", fontsize="x-small", ncol=3)

# Queue for incoming serial data
data_queue = queue.Queue()

def update_plot(frame):
    if not data_queue.empty():
        new_matrix = data_queue.get()

        for i in range(5):
            for j in range(3):
                val = new_matrix[i][j]

                # Update rolling data
                if len(time_series_data[i][j]) >= max_history:
                    time_series_data[i][j].pop(0)
                time_series_data[i][j].append(val)

                # Update line
                lines[i][j].set_ydata(time_series_data[i][j])
                lines[i][j].set_xdata(x_vals[-len(time_series_data[i][j]):])

                # Optional: update heatmap text (commented)
                # cell_texts[i][j].set_text(f"{val:.2f}")

        # heatmap.set_data(new_matrix)

    # Return list of updated artists
    all_lines = [line for row in lines for line in row]
    # return [heatmap] + [text for row in cell_texts for text in row] + all_lines
    return all_lines

def read_arduino_data():
    while True:
        try:
            line = ser.readline().decode('utf-8', errors='ignore').strip()
            if "Matrix updated:" in line:
                new_matrix = np.zeros((5, 3))
                for i in range(5):
                    row_data = ser.readline().decode('utf-8', errors='ignore').strip().split(",")
                    if len(row_data) == 3:
                        new_matrix[i] = [float(val) for val in row_data]
                data_queue.put(new_matrix)
        except Exception as e:
            print(f"Serial read error: {e}")

# Background serial reader
data_thread = threading.Thread(target=read_arduino_data, daemon=True)
data_thread.start()

# Animation loop
ani = animation.FuncAnimation(fig, update_plot, interval=50, blit=False)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/b5/cbnlm0vn1j54xy3c75jt4gwc0000gn/T/ipykernel_11626/4092630719.py:91: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = animation.FuncAnimation(fig, update_plot, interval=50, blit=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.animation import FuncAnimation, FFMpegWriter

# --- Load CSV ---
CSV_FILE = "heatmap_log.csv"
df = pd.read_csv(CSV_FILE)
timestamps = df['timestamp'].to_numpy()
frames = [np.array(df.iloc[i, 1:]).reshape((5, 3)) for i in range(len(df))]

# Compute per-frame delay in milliseconds
intervals = np.diff(timestamps, prepend=timestamps[0]) * 1000
intervals = np.round(intervals).astype(int)
avg_interval = int(np.mean(intervals))  # use average for fixed-FPS video

# --- Set up plot ---
fig, ax = plt.subplots()
cmap = mcolors.LinearSegmentedColormap.from_list("custom", ["red", "yellow", "green"])
matrix = np.zeros((5, 3))
heatmap = ax.imshow(matrix, cmap=cmap, vmin=0, vmax=3.3)
plt.colorbar(heatmap, label="Voltage (V)")
ax.set_xticks(np.arange(3))
ax.set_yticks(np.arange(5))
ax.set_xticklabels(["CH1", "CH2", "CH3"])
ax.set_yticklabels(["CH1", "CH2", "CH3", "CH4", "CH5"])
plt.title("5x3 Voltage Matrix Playback")
cell_texts = [[ax.text(j, i, "", ha="center", va="center", color="black", fontsize=12)
               for j in range(3)] for i in range(5)]

# --- Animation update ---
def update(i):
    matrix = frames[i]
    heatmap.set_data(matrix)
    for row in range(5):
        for col in range(3):
            cell_texts[row][col].set_text(f"{matrix[row][col]:.2f}")
    return [heatmap] + [text for row in cell_texts for text in row]

# --- Create animation ---
ani = FuncAnimation(fig, update, frames=len(frames), interval=avg_interval, blit=True)

# --- Save as MP4 ---
writer = FFMpegWriter(fps=1000 / avg_interval)
ani.save("heatmap_playback.mp4", writer=writer)

print("Video saved as 'heatmap_playback.mp4'")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 10
# ...

# %% [markdown]
# Playback

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.animation import FuncAnimation, FFMpegWriter

# --- Load CSV ---
CSV_FILE = "heatmap_log.csv"
df = pd.read_csv(CSV_FILE)
timestamps = df['timestamp'].to_numpy()
frames = [np.array(df.iloc[i, 1:]).reshape((5, 3)) for i in range(len(df))]

# Compute per-frame delay in milliseconds
intervals = np.diff(timestamps, prepend=timestamps[0]) * 1000
intervals = np.round(intervals).astype(int)
avg_interval = int(np.mean(intervals))  # use average for fixed-FPS video

# --- Set up plot ---
fig, ax = plt.subplots()
cmap = mcolors.LinearSegmentedColormap.from_list("custom", ["red", "yellow", "green"])
matrix = np.zeros((5, 3))
heatmap = ax.imshow(matrix, cmap=cmap, vmin=0, vmax=3.3)
plt.colorbar(heatmap, label="Voltage (V)")
ax.set_xticks(np.arange(3))
ax.set_yticks(np.arange(5))
ax.set_xticklabels(["CH1", "CH2", "CH3"])
ax.set_yticklabels(["CH1", "CH2", "CH3", "CH4", "CH5"])
plt.title("5x3 Voltage Matrix Playback")
cell_texts = [[ax.text(j, i, "", ha="center", va="center", color="black", fontsize=12)
               for j in range(3)] for i in range(5)]

# --- Animation update ---
def update(i):
    matrix = frames[i]
    heatmap.set_data(matrix)
    for row in range(5):
        for col in range(3):
            cell_texts[row][col].set_text(f"{matrix[row][col]:.2f}")
    return [heatmap] + [text for row in cell_texts for text in row]

# --- Create animation ---
ani = FuncAnimation(fig, update, frames=len(frames), interval=avg_interval, blit=True)

# --- Save as MP4 ---
writer = FFMpegWriter(fps=1000 / avg_interval)
ani.save("heatmap_playback.mp4", writer=writer)

print("Video saved as 'heatmap_playback.mp4'")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 46
#      44 # --- Save as MP4 ---
#      45 writer = FFMpegWriter(fps=1000 / avg_interval)
# ---> 46 ani.save("heatmap_playback.mp4", writer=writer)
#      48 print("Video saved as 'heatmap_playback.mp4'")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/animation.py:1069, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1065 savefig_kwargs['transparent'] = False   # just to be safe!
#    1066 # canvas._is_saving = True makes the draw_event animation-starting
#    1067 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1068 # widget (both are likewise done in savefig()).
# -> 1069 with writer.saving(self._fig, filename, dpi), \
# ...
