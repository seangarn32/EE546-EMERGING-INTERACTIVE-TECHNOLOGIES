# %%
import matplotlib
import serial
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import threading
import queue
import time
import matplotlib.animation as animation

# %%
SERIAL_PORT = '/dev/tty.usbserial-0001'     # Change this based on your ESP32 port
BAUD_RATE = 250000       # Match the ESP32 code
ser = serial.Serial(SERIAL_PORT, BAUD_RATE, timeout=0.05)

matplotlib.use('TkAgg')


cmap = mcolors.LinearSegmentedColormap.from_list("custom", ["red", "yellow", "green"])  # Create a red-yellow-green gradient color map
fig, ax = plt.subplots()                   # Create the plot figure and axes
matrix = np.zeros((5, 3))                  # Initialize an empty 4x4 matrix
heatmap = ax.imshow(matrix, cmap=cmap, vmin=0, vmax=3.3)  # Plot the heatmap with defined colormap and voltage range
cbar = plt.colorbar(heatmap, label="Voltage (V)")         # Add a colorbar legend to the side

ax.set_xticks(np.arange(3))                             # Set X-axis ticks from 0 to 3
ax.set_yticks(np.arange(5))                             # Set Y-axis ticks from 0 to 3
ax.set_xticklabels(["CH1", "CH2", "CH3"])        # Label columns as CH1–CH4
ax.set_yticklabels(["CH1", "CH2", "CH3", "CH4", "CH5"])        # Label rows as CH1–CH4
plt.title("5x3 Matrix Voltage Visualization")           # Add a title to the plot

cell_texts = [[ax.text(j, i, "", ha="center", va="center", color="black", fontsize=12)
               for j in range(3)] for i in range(5)]

data_queue = queue.Queue()

def update_plot(frame):                               # This function runs every 50 ms from the animation timer
    if not data_queue.empty():                        # If new matrix data is available
        new_matrix = data_queue.get()                 # Retrieve the newest matrix from the queue
        heatmap.set_data(new_matrix)                  # Update heatmap color data

        for i in range(5):                            # Loop over rows
            for j in range(3):                        # Loop over columns
                cell_texts[i][j].set_text(f"{new_matrix[i][j]:.2f}")  # Update cell text with 2 decimal places
                print(cell_texts[i][j])
    return [heatmap] + [text for row in cell_texts for text in row]

def read_arduino_data():                                           # Define a background function for continuous serial reading
    while True:                                                    # Infinite loop
        try:
            line = ser.readline().decode('utf-8', errors='ignore').strip()  # Read a line from serial, decode it
            print(f"Serial line: {line}")
            if "Matrix updated:" in line:                          # If the trigger line is received
                new_matrix = np.zeros((5, 3))                      # Initialize new matrix to fill

                for i in range(5):                                 # Expect 4 lines of row data
                    row_data = ser.readline().decode('utf-8', errors='ignore').strip().split(",")  # Read and split by comma
                    print(row_data)
                    if len(row_data) == 3:                         # Ensure exactly 4 values per row
                        new_matrix[i] = [float(val) for val in row_data]  # Convert strings to floats and store

                data_queue.put(new_matrix)                         # Push the matrix into the data queue
        except Exception as e:                                     # If there's an error, print it
            print(f"Serial read error: {e}")                       # Print error to console

data_thread = threading.Thread(target=read_arduino_data, daemon=True)  # Create a daemon thread that runs serial reading
data_thread.start()                                                    # Start the thread

ani = animation.FuncAnimation(fig, update_plot, interval=50, blit=True)  # Start the animation; update every 50ms (20Hz)
plt.show()                                                     # Show the matplotlib GUI window
# Out:
# Serial line: Matrix updated:
# ['2.2083', '2.0273', '2.2924']
# ['1.9217', '1.8116', '1.9741']
# ['2.1726', '2.1288', '2.2478']
# ['2.2357', '2.2927', '2.4090']
# ['2.1745', '2.2360', '2.4001']
# Serial line: Matrix updated:
# ['2.2078', '2.0265', '2.2900']
# ['1.9209', '1.8092', '1.9727']
# ['2.1726', '2.1285', '2.2486']
# ['2.2352', '2.2895', '2.4068']
# ['2.1761', '2.2357', '2.3982']
# Serial line: Matrix updated:
# ['2.2102', '2.0297', '2.2929']
# ['1.9220', '1.8100', '1.9727']
# ['2.1742', '2.1277', '2.2467']
# ['2.2333', '2.2897', '2.4063']
# ['2.1747', '2.2330', '2.3977']
# Serial line: Matrix updated:
# ['2.2094', '2.0313', '2.2897']
# ['1.9212', '1.8116', '1.9727']
# ['2.1742', '2.1294', '2.2470']
# ['2.2365', '2.2913', '2.4052']
# ['2.1750', '2.2352', '2.3982']
# Serial line: Matrix updated:
# ['2.2110', '2.0329', '2.2897']
# ['1.9212', '1.8097', '1.9722']
# ['2.1737', '2.1291', '2.2446']
# ['2.2341', '2.2913', '2.4036']
# ['2.1756', '2.2363', '2.3977']
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.24')
# Text(1, 3, '2.29')
# Text(2, 3, '2.41')
# Text(0, 4, '2.17')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.24')
# Text(1, 3, '2.29')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line: Matrix updated:
# ['2.2097', '2.0270', '2.2865']
# ['1.9206', '1.8092', '1.9701']
# ['2.1715', '2.1275', '2.2438']
# ['2.2336', '2.2903', '2.4031']
# ['2.1769', '2.2368', '2.3982']
# Serial line:
# /var/folders/b5/cbnlm0vn1j54xy3c75jt4gwc0000gn/T/ipykernel_22244/490885734.py:57: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = animation.FuncAnimation(fig, update_plot, interval=50, blit=True)  # Start the animation; update every 50ms (20Hz)
# Serial line: Matrix updated:
# ['2.2078', '2.0286', '2.2865']
# ['1.9196', '1.8089', '1.9703']
# ['2.1707', '2.1275', '2.2446']
# ['2.2320', '2.2905', '2.4017']
# ['2.1734', '2.2341', '2.3939']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2091', '2.0302', '2.2876']
# ['1.9209', '1.8097', '1.9684']
# ['2.1713', '2.1277', '2.2443']
# ['2.2336', '2.2897', '2.4012']
# ['2.1747', '2.2314', '2.3937']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2073', '2.0294', '2.2865']
# ['1.9209', '1.8089', '1.9709']
# ['2.1694', '2.1277', '2.2427']
# ['2.2336', '2.2919', '2.4033']
# ['2.1729', '2.2341', '2.3961']
# Serial line:
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.41')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.40')
# Serial line:
# Serial line: Matrix updated:
# ['2.2075', '2.0267', '2.2860']
# ['1.9212', '1.8100', '1.9717']
# ['2.1731', '2.1283', '2.2446']
# ['2.2360', '2.2916', '2.4031']
# ['2.1739', '2.2325', '2.3942']
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.24')
# Text(1, 3, '2.29')
# Text(2, 3, '2.41')
# Text(0, 4, '2.17')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line: Matrix updated:
# ['2.2075', '2.0267', '2.2854']
# ['1.9212', '1.8086', '1.9693']
# ['2.1734', '2.1277', '2.2459']
# ['2.2381', '2.2908', '2.4031']
# ['2.1745', '2.2360', '2.3947']
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.39')
# Serial line:
# Serial line: Matrix updated:
# ['2.2102', '2.0292', '2.2876']
# ['1.9212', '1.8094', '1.9703']
# ['2.1726', '2.1269', '2.2467']
# ['2.2338', '2.2913', '2.4036']
# ['2.1747', '2.2347', '2.3974']
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.39')
# Serial line:
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.40')
# Serial line:
# Serial line: Matrix updated:
# ['2.2099', '2.0308', '2.2868']
# ['1.9204', '1.8073', '1.9687']
# ['2.1707', '2.1277', '2.2462']
# ['2.2347', '2.2916', '2.4028']
# ['2.1756', '2.2371', '2.3985']
# Serial line:
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.24')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.39')
# Serial line:
# Serial line: Matrix updated:
# ['2.2075', '2.0292', '2.2857']
# ['1.9196', '1.8075', '1.9698']
# ['2.1721', '2.1275', '2.2451']
# ['2.2347', '2.2889', '2.4017']
# ['2.1769', '2.2381', '2.3980']
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.24')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.17')
# Text(1, 4, '2.24')
# Text(2, 4, '2.39')
# Serial line:
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.40')
# Serial line:
# Serial line: Matrix updated:
# ['2.2073', '2.0251', '2.2830']
# ['1.9201', '1.8075', '1.9682']
# ['2.1707', '2.1280', '2.2443']
# ['2.2328', '2.2889', '2.4001']
# ['2.1739', '2.2336', '2.3931']
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line: Matrix updated:
# ['2.2056', '2.0243', '2.2833']
# ['1.9212', '1.8084', '1.9695']
# ['2.1721', '2.1283', '2.2462']
# ['2.2328', '2.2895', '2.3982']
# ['2.1772', '2.2363', '2.3961']
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.28')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.39')
# Serial line:
# Text(0, 0, '2.21')
# Text(1, 0, '2.02')
# Text(2, 0, '2.28')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line: Matrix updated:
# ['2.2048', '2.0241', '2.2822']
# ['1.9201', '1.8073', '1.9687']
# ['2.1723', '2.1283', '2.2449']
# ['2.2325', '2.2905', '2.4001']
# ['2.1750', '2.2365', '2.3939']
# Text(0, 0, '2.20')
# Text(1, 0, '2.02')
# Text(2, 0, '2.28')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.17')
# Text(1, 4, '2.24')
# Text(2, 4, '2.39')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2094', '2.0318', '2.2860']
# ['1.9196', '1.8097', '1.9684']
# ['2.1721', '2.1275', '2.2446']
# ['2.2338', '2.2908', '2.4023']
# ['2.1745', '2.2347', '2.3931']
# Serial line:
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.39')
# Serial line:
# Serial line: Matrix updated:
# ['2.2094', '2.0281', '2.2833']
# ['1.9209', '1.8075', '1.9674']
# ['2.1715', '2.1288', '2.2441']
# ['2.2341', '2.2892', '2.3996']
# ['2.1745', '2.2360', '2.3956']
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.28')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.17')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2062', '2.0251', '2.2825']
# ['1.9198', '1.8075', '1.9650']
# ['2.1713', '2.1277', '2.2435']
# ['2.2347', '2.2908', '2.3996']
# ['2.1745', '2.2344', '2.3923']
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.28')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.23')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.39')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2118', '2.0316', '2.2889']
# ['1.9212', '1.8097', '1.9698']
# ['2.1713', '2.1272', '2.2454']
# ['2.2441', '2.2943', '2.4055']
# ['2.1772', '2.2341', '2.3950']
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.24')
# Text(1, 3, '2.29')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.23')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2091', '2.0278', '2.2881']
# ['1.9212', '1.8100', '1.9663']
# ['2.1713', '2.1280', '2.2430']
# ['2.2381', '2.2911', '2.4015']
# ['2.1761', '2.2333', '2.3939']
# Text(0, 0, '2.21')
# Text(1, 0, '2.03')
# Text(2, 0, '2.29')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.24')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.18')
# Text(1, 4, '2.23')
# Text(2, 4, '2.39')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2387', '2.0673', '2.3163']
# ['1.9198', '1.8097', '1.9722']
# ['2.1729', '2.1280', '2.2457']
# ['2.2365', '2.2919', '2.4036']
# ['2.1772', '2.2371', '2.3972']
# Serial line:
# Text(0, 0, '2.24')
# Text(1, 0, '2.07')
# Text(2, 0, '2.32')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.24')
# Text(1, 3, '2.29')
# Text(2, 3, '2.40')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line: Matrix updated:
# ['2.2199', '2.0466', '2.2989']
# ['1.9212', '1.8089', '1.9676']
# ['2.1731', '2.1275', '2.2457']
# ['2.2629', '2.3080', '2.4130']
# ['2.1785', '2.2363', '2.3945']
# Text(0, 0, '2.22')
# Text(1, 0, '2.05')
# Text(2, 0, '2.30')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.39')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2475', '2.0995', '2.3209']
# ['1.9206', '1.8137', '1.9722']
# ['2.1758', '2.1285', '2.2441']
# ['2.2655', '2.3088', '2.4127']
# ['2.1790', '2.2390', '2.3980']
# Text(0, 0, '2.25')
# Text(1, 0, '2.10')
# Text(2, 0, '2.32')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.27')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2502', '2.1003', '2.3179']
# ['1.9209', '1.8116', '1.9693']
# ['2.1737', '2.1275', '2.2435']
# ['2.2610', '2.3080', '2.4117']
# ['2.1780', '2.2363', '2.3950']
# Text(0, 0, '2.25')
# Text(1, 0, '2.10')
# Text(2, 0, '2.32')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2419', '2.0891', '2.3091']
# ['1.9204', '1.8116', '1.9650']
# ['2.1705', '2.1277', '2.2430']
# ['2.2588', '2.3074', '2.4111']
# ['2.1774', '2.2373', '2.3937']
# Text(0, 0, '2.24')
# Text(1, 0, '2.09')
# Text(2, 0, '2.31')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.39')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2419', '2.0888', '2.3096']
# ['1.9196', '1.8116', '1.9644']
# ['2.1713', '2.1272', '2.2408']
# ['2.2586', '2.3069', '2.4111']
# ['2.1774', '2.2344', '2.3907']
# Text(0, 0, '2.24')
# Text(1, 0, '2.09')
# Text(2, 0, '2.31')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.96')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.23')
# Text(2, 4, '2.39')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2564', '2.1127', '2.3314']
# ['1.9201', '1.8116', '1.9719']
# ['2.1707', '2.1275', '2.2449']
# ['2.2586', '2.3069', '2.4114']
# ['2.1758', '2.2363', '2.3953']
# Serial line:
# Text(0, 0, '2.26')
# Text(1, 0, '2.11')
# Text(2, 0, '2.33')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line: Matrix updated:
# ['2.2500', '2.0998', '2.3220']
# ['1.9206', '1.8102', '1.9695']
# ['2.1713', '2.1275', '2.2430']
# ['2.2567', '2.3053', '2.4119']
# ['2.1756', '2.2373', '2.3939']
# Text(0, 0, '2.25')
# Text(1, 0, '2.10')
# Text(2, 0, '2.32')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.97')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.24')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.39')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2569', '2.1020', '2.3330']
# ['1.9265', '1.8196', '1.9988']
# ['2.1745', '2.1291', '2.2508']
# ['2.2561', '2.3061', '2.4162']
# ['2.1774', '2.2357', '2.4001']
# Text(0, 0, '2.26')
# Text(1, 0, '2.10')
# Text(2, 0, '2.33')
# Text(0, 1, '1.93')
# Text(1, 1, '1.82')
# Text(2, 1, '2.00')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.42')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2529', '2.0944', '2.3249']
# ['1.9239', '1.8178', '1.9969']
# ['2.1756', '2.1283', '2.2494']
# ['2.2556', '2.3042', '2.4136']
# ['2.1747', '2.2333', '2.4001']
# Text(0, 0, '2.25')
# Text(1, 0, '2.09')
# Text(2, 0, '2.32')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '2.00')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.30')
# Text(2, 3, '2.41')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2645', '2.1162', '2.3348']
# ['1.9236', '1.8161', '1.9902']
# ['2.1739', '2.1291', '2.2484']
# ['2.2564', '2.3029', '2.4119']
# ['2.1742', '2.2338', '2.3980']
# Text(0, 0, '2.26')
# Text(1, 0, '2.12')
# Text(2, 0, '2.33')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '1.99')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.30')
# Text(2, 3, '2.41')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2561', '2.1057', '2.3319']
# ['1.9214', '1.8145', '1.9870']
# ['2.1723', '2.1269', '2.2467']
# ['2.2543', '2.3034', '2.4119']
# ['2.1726', '2.2328', '2.3972']
# Serial line:
# Text(0, 0, '2.26')
# Text(1, 0, '2.11')
# Text(2, 0, '2.33')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.99')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.25')
# Text(1, 3, '2.30')
# Text(2, 3, '2.41')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.40')
# Serial line:
# Serial line: Matrix updated:
# ['2.2454', '2.0891', '2.3206']
# ['1.9214', '1.8124', '1.9870']
# ['2.1739', '2.1272', '2.2478']
# ['2.2564', '2.3029', '2.4114']
# ['2.1726', '2.2341', '2.3977']
# Text(0, 0, '2.25')
# Text(1, 0, '2.09')
# Text(2, 0, '2.32')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.99')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.30')
# Text(2, 3, '2.41')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2427', '2.0848', '2.3166']
# ['1.9214', '1.8118', '1.9838']
# ['2.1721', '2.1272', '2.2459']
# ['2.2556', '2.3042', '2.4117']
# ['2.1737', '2.2336', '2.3969']
# Text(0, 0, '2.24')
# Text(1, 0, '2.08')
# Text(2, 0, '2.32')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.98')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.30')
# Text(2, 3, '2.41')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2419', '2.0807', '2.3134']
# ['1.9214', '1.8105', '1.9813']
# ['2.1710', '2.1269', '2.2470']
# ['2.2559', '2.3026', '2.4114']
# ['2.1758', '2.2352', '2.3966']
# Text(0, 0, '2.24')
# Text(1, 0, '2.08')
# Text(2, 0, '2.31')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.98')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.30')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2561', '2.1052', '2.3314']
# ['1.9209', '1.8140', '1.9867']
# ['2.1734', '2.1277', '2.2497']
# ['2.2556', '2.3037', '2.4130']
# ['2.1731', '2.2314', '2.3982']
# Text(0, 0, '2.26')
# Text(1, 0, '2.11')
# Text(2, 0, '2.33')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.99')
# Text(0, 2, '2.17')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.30')
# Text(2, 3, '2.41')
# Text(0, 4, '2.17')
# Text(1, 4, '2.23')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2790', '2.1304', '2.3577']
# ['1.9225', '1.8135', '1.9932']
# ['2.1758', '2.1291', '2.2535']
# ['2.2561', '2.3045', '2.4149']
# ['2.1769', '2.2363', '2.4017']
# Serial line:
# Text(0, 0, '2.28')
# Text(1, 0, '2.13')
# Text(2, 0, '2.36')
# Text(0, 1, '1.92')
# Text(1, 1, '1.81')
# Text(2, 1, '1.99')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.30')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line: Matrix updated:
# ['2.2427', '2.0821', '2.3126']
# ['1.9244', '1.8178', '1.9862']
# ['2.1753', '2.1288', '2.2489']
# ['2.2578', '2.3053', '2.4133']
# ['2.1780', '2.2381', '2.3980']
# Text(0, 0, '2.24')
# Text(1, 0, '2.08')
# Text(2, 0, '2.31')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '1.99')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2266', '2.0523', '2.3002']
# ['1.9236', '1.8172', '1.9805']
# ['2.1753', '2.1275', '2.2473']
# ['2.2572', '2.3040', '2.4117']
# ['2.1788', '2.2395', '2.3982']
# Text(0, 0, '2.23')
# Text(1, 0, '2.05')
# Text(2, 0, '2.30')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '1.98')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.30')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2653', '2.1151', '2.3316']
# ['1.9271', '1.8180', '1.9776']
# ['2.1782', '2.1318', '2.2508']
# ['2.2572', '2.3056', '2.4130']
# ['2.1793', '2.2422', '2.4001']
# Text(0, 0, '2.27')
# Text(1, 0, '2.12')
# Text(2, 0, '2.33')
# Text(0, 1, '1.93')
# Text(1, 1, '1.82')
# Text(2, 1, '1.98')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2564', '2.0987', '2.3203']
# ['1.9274', '1.8167', '1.9738']
# ['2.1772', '2.1307', '2.2473']
# ['2.2583', '2.3072', '2.4122']
# ['2.1807', '2.2424', '2.4007']
# Text(0, 0, '2.26')
# Text(1, 0, '2.10')
# Text(2, 0, '2.32')
# Text(0, 1, '1.93')
# Text(1, 1, '1.82')
# Text(2, 1, '1.97')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2586', '2.1071', '2.3249']
# ['1.9247', '1.8167', '1.9749']
# ['2.1777', '2.1294', '2.2486']
# ['2.2578', '2.3066', '2.4122']
# ['2.1839', '2.2457', '2.4033']
# Serial line:
# Text(0, 0, '2.26')
# Text(1, 0, '2.11')
# Text(2, 0, '2.32')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '1.97')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.25')
# Text(2, 4, '2.40')
# Serial line:
# Serial line: Matrix updated:
# ['2.2825', '2.1439', '2.3442']
# ['1.9247', '1.8180', '1.9738']
# ['2.1766', '2.1294', '2.2492']
# ['2.2578', '2.3069', '2.4127']
# ['2.1820', '2.2449', '2.4042']
# Text(0, 0, '2.28')
# Text(1, 0, '2.14')
# Text(2, 0, '2.34')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '1.97')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2962', '2.1578', '2.3596']
# ['1.9300', '1.8186', '1.9800']
# ['2.1777', '2.1315', '2.2513']
# ['2.2569', '2.3074', '2.4152']
# ['2.1812', '2.2443', '2.4039']
# Text(0, 0, '2.30')
# Text(1, 0, '2.16')
# Text(2, 0, '2.36')
# Text(0, 1, '1.93')
# Text(1, 1, '1.82')
# Text(2, 1, '1.98')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.42')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2870', '2.1495', '2.3510']
# ['1.9257', '1.8178', '1.9754']
# ['2.1774', '2.1320', '2.2494']
# ['2.2569', '2.3074', '2.4114']
# ['2.1823', '2.2435', '2.4012']
# Text(0, 0, '2.29')
# Text(1, 0, '2.15')
# Text(2, 0, '2.35')
# Text(0, 1, '1.93')
# Text(1, 1, '1.82')
# Text(2, 1, '1.98')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2873', '2.1468', '2.3472']
# ['1.9274', '1.8169', '1.9757']
# ['2.1790', '2.1320', '2.2513']
# ['2.2567', '2.3061', '2.4119']
# ['2.1809', '2.2432', '2.4007']
# Text(0, 0, '2.29')
# Text(1, 0, '2.15')
# Text(2, 0, '2.35')
# Text(0, 1, '1.93')
# Text(1, 1, '1.82')
# Text(2, 1, '1.98')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2717', '2.1224', '2.3362']
# ['1.9265', '1.8169', '1.9754']
# ['2.1772', '2.1302', '2.2497']
# ['2.2567', '2.3066', '2.4136']
# ['2.1820', '2.2430', '2.4007']
# Text(0, 0, '2.27')
# Text(1, 0, '2.12')
# Text(2, 0, '2.34')
# Text(0, 1, '1.93')
# Text(1, 1, '1.82')
# Text(2, 1, '1.98')
# Text(0, 2, '2.18')
# Text(1, 2, '2.13')
# Text(2, 2, '2.25')
# Text(0, 3, '2.26')
# Text(1, 3, '2.31')
# Text(2, 3, '2.41')
# Text(0, 4, '2.18')
# Text(1, 4, '2.24')
# Text(2, 4, '2.40')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.3682', '2.2467', '2.5183']
# ['1.9980', '1.8900', '2.1933']
# ['2.3620', '2.3504', '2.5694']
# ['1.7691', '1.1242', '2.2199']
# ['2.4619', '2.4520', '2.6824']
# Serial line:
# Text(0, 0, '2.37')
# Text(1, 0, '2.25')
# Text(2, 0, '2.52')
# Text(0, 1, '2.00')
# Text(1, 1, '1.89')
# Text(2, 1, '2.19')
# Text(0, 2, '2.36')
# Text(1, 2, '2.35')
# Text(2, 2, '2.57')
# Text(0, 3, '1.77')
# Text(1, 3, '1.12')
# Text(2, 3, '2.22')
# Text(0, 4, '2.46')
# Text(1, 4, '2.45')
# Text(2, 4, '2.68')
# Serial line:
# Serial line: Matrix updated:
# ['2.2416', '2.1135', '2.3883']
# ['1.9212', '1.8234', '2.0896']
# ['2.2946', '2.2693', '2.4571']
# ['1.6410', '0.7734', '2.0619']
# ['2.3483', '2.3601', '2.5908']
# Text(0, 0, '2.24')
# Text(1, 0, '2.11')
# Text(2, 0, '2.39')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '2.09')
# Text(0, 2, '2.29')
# Text(1, 2, '2.27')
# Text(2, 2, '2.46')
# Text(0, 3, '1.64')
# Text(1, 3, '0.77')
# Text(2, 3, '2.06')
# Text(0, 4, '2.35')
# Text(1, 4, '2.36')
# Text(2, 4, '2.59')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2398', '2.1119', '2.3843']
# ['1.9201', '1.8202', '2.0622']
# ['2.2685', '2.2459', '2.4350']
# ['1.6399', '0.8897', '2.0622']
# ['2.3743', '2.3776', '2.6024']
# Text(0, 0, '2.24')
# Text(1, 0, '2.11')
# Text(2, 0, '2.38')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '2.06')
# Text(0, 2, '2.27')
# Text(1, 2, '2.25')
# Text(2, 2, '2.44')
# Text(0, 3, '1.64')
# Text(1, 3, '0.89')
# Text(2, 3, '2.06')
# Text(0, 4, '2.37')
# Text(1, 4, '2.38')
# Text(2, 4, '2.60')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2688', '2.1226', '2.4111']
# ['1.9464', '1.8331', '2.0858']
# ['2.3056', '2.2811', '2.4657']
# ['1.9714', '1.9032', '2.3362']
# ['2.4197', '2.4463', '2.6319']
# Text(0, 0, '2.27')
# Text(1, 0, '2.12')
# Text(2, 0, '2.41')
# Text(0, 1, '1.95')
# Text(1, 1, '1.83')
# Text(2, 1, '2.09')
# Text(0, 2, '2.31')
# Text(1, 2, '2.28')
# Text(2, 2, '2.47')
# Text(0, 3, '1.97')
# Text(1, 3, '1.90')
# Text(2, 3, '2.34')
# Text(0, 4, '2.42')
# Text(1, 4, '2.45')
# Text(2, 4, '2.63')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.3061', '2.1283', '2.4025']
# ['1.9784', '1.8527', '2.0837']
# ['2.2618', '2.2320', '2.3990']
# ['2.5095', '2.5167', '2.6620']
# ['2.2870', '2.3330', '2.5371']
# Text(0, 0, '2.31')
# Text(1, 0, '2.13')
# Text(2, 0, '2.40')
# Text(0, 1, '1.98')
# Text(1, 1, '1.85')
# Text(2, 1, '2.08')
# Text(0, 2, '2.26')
# Text(1, 2, '2.23')
# Text(2, 2, '2.40')
# Text(0, 3, '2.51')
# Text(1, 3, '2.52')
# Text(2, 3, '2.66')
# Text(0, 4, '2.29')
# Text(1, 4, '2.33')
# Text(2, 4, '2.54')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2830', '2.1087', '2.3840']
# ['1.9652', '1.8438', '2.0622']
# ['2.2325', '2.2027', '2.3596']
# ['2.4657', '2.4960', '2.6274']
# ['2.2403', '2.2943', '2.4958']
# Text(0, 0, '2.28')
# Text(1, 0, '2.11')
# Text(2, 0, '2.38')
# Text(0, 1, '1.97')
# Text(1, 1, '1.84')
# Text(2, 1, '2.06')
# Text(0, 2, '2.23')
# Text(1, 2, '2.20')
# Text(2, 2, '2.36')
# Text(0, 3, '2.47')
# Text(1, 3, '2.50')
# Text(2, 3, '2.63')
# Text(0, 4, '2.24')
# Text(1, 4, '2.29')
# Text(2, 4, '2.50')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2725', '2.0899', '2.3698']
# ['1.9633', '1.8435', '2.0598']
# ['2.2306', '2.1992', '2.3569']
# ['2.4979', '2.5210', '2.6311']
# ['2.2446', '2.3010', '2.4906']
# Text(0, 0, '2.27')
# Text(1, 0, '2.09')
# Text(2, 0, '2.37')
# Text(0, 1, '1.96')
# Text(1, 1, '1.84')
# Text(2, 1, '2.06')
# Text(0, 2, '2.23')
# Text(1, 2, '2.20')
# Text(2, 2, '2.36')
# Text(0, 3, '2.50')
# Text(1, 3, '2.52')
# Text(2, 3, '2.63')
# Text(0, 4, '2.24')
# Text(1, 4, '2.30')
# Text(2, 4, '2.49')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2715', '2.0947', '2.3738']
# ['1.9607', '1.8406', '2.0539']
# ['2.2293', '2.1997', '2.3596']
# ['2.4681', '2.4987', '2.6105']
# ['2.2384', '2.2951', '2.4888']
# Text(0, 0, '2.27')
# Text(1, 0, '2.09')
# Text(2, 0, '2.37')
# Text(0, 1, '1.96')
# Text(1, 1, '1.84')
# Text(2, 1, '2.05')
# Text(0, 2, '2.23')
# Text(1, 2, '2.20')
# Text(2, 2, '2.36')
# Text(0, 3, '2.47')
# Text(1, 3, '2.50')
# Text(2, 3, '2.61')
# Text(0, 4, '2.24')
# Text(1, 4, '2.30')
# Text(2, 4, '2.49')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2744', '2.0979', '2.3730']
# ['1.9582', '1.8398', '2.0525']
# ['2.2215', '2.1938', '2.3566']
# ['2.4565', '2.4877', '2.5970']
# ['2.2301', '2.2868', '2.4812']
# Text(0, 0, '2.27')
# Text(1, 0, '2.10')
# Text(2, 0, '2.37')
# Text(0, 1, '1.96')
# Text(1, 1, '1.84')
# Text(2, 1, '2.05')
# Text(0, 2, '2.22')
# Text(1, 2, '2.19')
# Text(2, 2, '2.36')
# Text(0, 3, '2.46')
# Text(1, 3, '2.49')
# Text(2, 3, '2.60')
# Text(0, 4, '2.23')
# Text(1, 4, '2.29')
# Text(2, 4, '2.48')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2653', '2.0829', '2.3639']
# ['1.9580', '1.8382', '2.0506']
# ['2.2199', '2.1890', '2.3510']
# ['2.4372', '2.4662', '2.5908']
# ['2.2244', '2.2822', '2.4740']
# Serial line:
# Text(0, 0, '2.27')
# Text(1, 0, '2.08')
# Text(2, 0, '2.36')
# Text(0, 1, '1.96')
# Text(1, 1, '1.84')
# Text(2, 1, '2.05')
# Text(0, 2, '2.22')
# Text(1, 2, '2.19')
# Text(2, 2, '2.35')
# Text(0, 3, '2.44')
# Text(1, 3, '2.47')
# Text(2, 3, '2.59')
# Text(0, 4, '2.22')
# Text(1, 4, '2.28')
# Text(2, 4, '2.47')
# Serial line:
# Serial line: Matrix updated:
# ['2.2578', '2.0622', '2.3571']
# ['1.9572', '1.8392', '2.0498']
# ['2.2183', '2.1871', '2.3499']
# ['2.4372', '2.4624', '2.5922']
# ['2.2204', '2.2806', '2.4748']
# Text(0, 0, '2.26')
# Text(1, 0, '2.06')
# Text(2, 0, '2.36')
# Text(0, 1, '1.96')
# Text(1, 1, '1.84')
# Text(2, 1, '2.05')
# Text(0, 2, '2.22')
# Text(1, 2, '2.19')
# Text(2, 2, '2.35')
# Text(0, 3, '2.44')
# Text(1, 3, '2.46')
# Text(2, 3, '2.59')
# Text(0, 4, '2.22')
# Text(1, 4, '2.28')
# Text(2, 4, '2.47')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2564', '2.0622', '2.3571']
# ['1.9537', '1.8366', '2.0477']
# ['2.2180', '2.1887', '2.3475']
# ['2.4364', '2.4670', '2.5916']
# ['2.2220', '2.2806', '2.4729']
# Text(0, 0, '2.26')
# Text(1, 0, '2.06')
# Text(2, 0, '2.36')
# Text(0, 1, '1.95')
# Text(1, 1, '1.84')
# Text(2, 1, '2.05')
# Text(0, 2, '2.22')
# Text(1, 2, '2.19')
# Text(2, 2, '2.35')
# Text(0, 3, '2.44')
# Text(1, 3, '2.47')
# Text(2, 3, '2.59')
# Text(0, 4, '2.22')
# Text(1, 4, '2.28')
# Text(2, 4, '2.47')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2508', '2.0592', '2.3459']
# ['1.9483', '1.8325', '2.0421']
# ['2.2118', '2.1799', '2.3389']
# ['2.4307', '2.4624', '2.5871']
# ['2.2196', '2.2768', '2.4678']
# Text(0, 0, '2.25')
# Text(1, 0, '2.06')
# Text(2, 0, '2.35')
# Text(0, 1, '1.95')
# Text(1, 1, '1.83')
# Text(2, 1, '2.04')
# Text(0, 2, '2.21')
# Text(1, 2, '2.18')
# Text(2, 2, '2.34')
# Text(0, 3, '2.43')
# Text(1, 3, '2.46')
# Text(2, 3, '2.59')
# Text(0, 4, '2.22')
# Text(1, 4, '2.28')
# Text(2, 4, '2.47')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2502', '2.0571', '2.3437']
# ['1.9488', '1.8328', '2.0423']
# ['2.2105', '2.1793', '2.3351']
# ['2.4240', '2.4533', '2.5731']
# ['2.2201', '2.2774', '2.4641']
# Text(0, 0, '2.25')
# Text(1, 0, '2.06')
# Text(2, 0, '2.34')
# Text(0, 1, '1.95')
# Text(1, 1, '1.83')
# Text(2, 1, '2.04')
# Text(0, 2, '2.21')
# Text(1, 2, '2.18')
# Text(2, 2, '2.34')
# Text(0, 3, '2.42')
# Text(1, 3, '2.45')
# Text(2, 3, '2.57')
# Text(0, 4, '2.22')
# Text(1, 4, '2.28')
# Text(2, 4, '2.46')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2510', '2.0600', '2.3518']
# ['1.9542', '1.8358', '2.0482']
# ['2.2169', '2.1842', '2.3437']
# ['2.4307', '2.4624', '2.5908']
# ['2.2255', '2.2814', '2.4724']
# Serial line:
# Text(0, 0, '2.25')
# Text(1, 0, '2.06')
# Text(2, 0, '2.35')
# Text(0, 1, '1.95')
# Text(1, 1, '1.84')
# Text(2, 1, '2.05')
# Text(0, 2, '2.22')
# Text(1, 2, '2.18')
# Text(2, 2, '2.34')
# Text(0, 3, '2.43')
# Text(1, 3, '2.46')
# Text(2, 3, '2.59')
# Text(0, 4, '2.23')
# Text(1, 4, '2.28')
# Text(2, 4, '2.47')
# Serial line:
# Serial line: Matrix updated:
# ['2.2467', '2.0552', '2.3442']
# ['1.9475', '1.8323', '2.0391']
# ['2.2145', '2.1815', '2.3343']
# ['2.4181', '2.4495', '2.5726']
# ['2.2183', '2.2760', '2.4657']
# Text(0, 0, '2.25')
# Text(1, 0, '2.06')
# Text(2, 0, '2.34')
# Text(0, 1, '1.95')
# Text(1, 1, '1.83')
# Text(2, 1, '2.04')
# Text(0, 2, '2.21')
# Text(1, 2, '2.18')
# Text(2, 2, '2.33')
# Text(0, 3, '2.42')
# Text(1, 3, '2.45')
# Text(2, 3, '2.57')
# Text(0, 4, '2.22')
# Text(1, 4, '2.28')
# Text(2, 4, '2.47')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2481', '2.0558', '2.3451']
# ['1.9494', '1.8328', '2.0380']
# ['2.2142', '2.1801', '2.3338']
# ['2.4141', '2.4447', '2.5672']
# ['2.2142', '2.2715', '2.4614']
# Text(0, 0, '2.25')
# Text(1, 0, '2.06')
# Text(2, 0, '2.35')
# Text(0, 1, '1.95')
# Text(1, 1, '1.83')
# Text(2, 1, '2.04')
# Text(0, 2, '2.21')
# Text(1, 2, '2.18')
# Text(2, 2, '2.33')
# Text(0, 3, '2.41')
# Text(1, 3, '2.44')
# Text(2, 3, '2.57')
# Text(0, 4, '2.21')
# Text(1, 4, '2.27')
# Text(2, 4, '2.46')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2430', '2.0504', '2.3429']
# ['1.9499', '1.8325', '2.0388']
# ['2.2132', '2.1812', '2.3351']
# ['2.4111', '2.4385', '2.5659']
# ['2.2086', '2.2688', '2.4619']
# Text(0, 0, '2.24')
# Text(1, 0, '2.05')
# Text(2, 0, '2.34')
# Text(0, 1, '1.95')
# Text(1, 1, '1.83')
# Text(2, 1, '2.04')
# Text(0, 2, '2.21')
# Text(1, 2, '2.18')
# Text(2, 2, '2.34')
# Text(0, 3, '2.41')
# Text(1, 3, '2.44')
# Text(2, 3, '2.57')
# Text(0, 4, '2.21')
# Text(1, 4, '2.27')
# Text(2, 4, '2.46')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2459', '2.0517', '2.3426']
# ['1.9470', '1.8328', '2.0391']
# ['2.2089', '2.1790', '2.3324']
# ['2.4117', '2.4431', '2.5696']
# ['2.2075', '2.2669', '2.4608']
# Serial line:
# Text(0, 0, '2.25')
# Text(1, 0, '2.05')
# Text(2, 0, '2.34')
# Text(0, 1, '1.95')
# Text(1, 1, '1.83')
# Text(2, 1, '2.04')
# Text(0, 2, '2.21')
# Text(1, 2, '2.18')
# Text(2, 2, '2.33')
# Text(0, 3, '2.41')
# Text(1, 3, '2.44')
# Text(2, 3, '2.57')
# Text(0, 4, '2.21')
# Text(1, 4, '2.27')
# Text(2, 4, '2.46')
# Serial line:
# Serial line: Matrix updated:
# ['2.2583', '2.0797', '2.3596']
# ['1.9491', '1.8360', '2.0469']
# ['2.2083', '2.1780', '2.3324']
# ['2.4179', '2.4520', '2.5774']
# ['2.2070', '2.2677', '2.4635']
# Text(0, 0, '2.26')
# Text(1, 0, '2.08')
# Text(2, 0, '2.36')
# Text(0, 1, '1.95')
# Text(1, 1, '1.84')
# Text(2, 1, '2.05')
# Text(0, 2, '2.21')
# Text(1, 2, '2.18')
# Text(2, 2, '2.33')
# Text(0, 3, '2.42')
# Text(1, 3, '2.45')
# Text(2, 3, '2.58')
# Text(0, 4, '2.21')
# Text(1, 4, '2.27')
# Text(2, 4, '2.46')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2561', '2.0622', '2.3593']
# ['1.9478', '1.8325', '2.0450']
# ['2.2064', '2.1739', '2.3263']
# ['2.4117', '2.4444', '2.5702']
# ['2.2056', '2.2666', '2.4627']
# Text(0, 0, '2.26')
# Text(1, 0, '2.06')
# Text(2, 0, '2.36')
# Text(0, 1, '1.95')
# Text(1, 1, '1.83')
# Text(2, 1, '2.04')
# Text(0, 2, '2.21')
# Text(1, 2, '2.17')
# Text(2, 2, '2.33')
# Text(0, 3, '2.41')
# Text(1, 3, '2.44')
# Text(2, 3, '2.57')
# Text(0, 4, '2.21')
# Text(1, 4, '2.27')
# Text(2, 4, '2.46')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2510', '2.0617', '2.3550']
# ['1.9472', '1.8323', '2.0437']
# ['2.2035', '2.1686', '2.3225']
# ['2.4060', '2.4372', '2.5680']
# ['2.2043', '2.2642', '2.4624']
# Text(0, 0, '2.25')
# Text(1, 0, '2.06')
# Text(2, 0, '2.35')
# Text(0, 1, '1.95')
# Text(1, 1, '1.83')
# Text(2, 1, '2.04')
# Text(0, 2, '2.20')
# Text(1, 2, '2.17')
# Text(2, 2, '2.32')
# Text(0, 3, '2.41')
# Text(1, 3, '2.44')
# Text(2, 3, '2.57')
# Text(0, 4, '2.20')
# Text(1, 4, '2.26')
# Text(2, 4, '2.46')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2513', '2.0622', '2.3518']
# ['1.9472', '1.8312', '2.0399']
# ['2.2048', '2.1694', '2.3222']
# ['2.4098', '2.4415', '2.5659']
# ['2.2056', '2.2663', '2.4589']
# Serial line:
# Text(0, 0, '2.25')
# Text(1, 0, '2.06')
# Text(2, 0, '2.35')
# Text(0, 1, '1.95')
# Text(1, 1, '1.83')
# Text(2, 1, '2.04')
# Text(0, 2, '2.20')
# Text(1, 2, '2.17')
# Text(2, 2, '2.32')
# Text(0, 3, '2.41')
# Text(1, 3, '2.44')
# Text(2, 3, '2.57')
# Text(0, 4, '2.21')
# Text(1, 4, '2.27')
# Text(2, 4, '2.46')
# Serial line:
# Serial line: Matrix updated:
# ['2.2481', '2.0622', '2.3480']
# ['1.9459', '1.8306', '2.0369']
# ['2.2040', '2.1683', '2.3222']
# ['2.4042', '2.4393', '2.5664']
# ['2.2048', '2.2647', '2.4589']
# Text(0, 0, '2.25')
# Text(1, 0, '2.06')
# Text(2, 0, '2.35')
# Text(0, 1, '1.95')
# Text(1, 1, '1.83')
# Text(2, 1, '2.04')
# Text(0, 2, '2.20')
# Text(1, 2, '2.17')
# Text(2, 2, '2.32')
# Text(0, 3, '2.40')
# Text(1, 3, '2.44')
# Text(2, 3, '2.57')
# Text(0, 4, '2.20')
# Text(1, 4, '2.26')
# Text(2, 4, '2.46')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2561', '2.1001', '2.4160']
# ['1.9582', '1.8575', '2.1479']
# ['2.2725', '2.2572', '2.4654']
# ['1.7176', '0.7970', '2.1046']
# ['2.3504', '2.3518', '2.5927']
# Text(0, 0, '2.26')
# Text(1, 0, '2.10')
# Text(2, 0, '2.42')
# Text(0, 1, '1.96')
# Text(1, 1, '1.86')
# Text(2, 1, '2.15')
# Text(0, 2, '2.27')
# Text(1, 2, '2.26')
# Text(2, 2, '2.47')
# Text(0, 3, '1.72')
# Text(1, 3, '0.80')
# Text(2, 3, '2.10')
# Text(0, 4, '2.35')
# Text(1, 4, '2.35')
# Text(2, 4, '2.59')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2196', '2.0622', '2.3762']
# ['1.9330', '1.8320', '2.1049']
# ['2.2465', '2.2150', '2.4251']
# ['1.6488', '0.6506', '2.0367']
# ['2.3228', '2.3241', '2.5648']
# Text(0, 0, '2.22')
# Text(1, 0, '2.06')
# Text(2, 0, '2.38')
# Text(0, 1, '1.93')
# Text(1, 1, '1.83')
# Text(2, 1, '2.10')
# Text(0, 2, '2.25')
# Text(1, 2, '2.21')
# Text(2, 2, '2.43')
# Text(0, 3, '1.65')
# Text(1, 3, '0.65')
# Text(2, 3, '2.04')
# Text(0, 4, '2.32')
# Text(1, 4, '2.32')
# Text(2, 4, '2.56')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2134', '2.0622', '2.3743']
# ['1.9228', '1.8234', '2.0950']
# ['2.2277', '2.1938', '2.4063']
# ['1.6227', '0.6329', '2.0165']
# ['2.3316', '2.3300', '2.5653']
# Text(0, 0, '2.21')
# Text(1, 0, '2.06')
# Text(2, 0, '2.37')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '2.10')
# Text(0, 2, '2.23')
# Text(1, 2, '2.19')
# Text(2, 2, '2.41')
# Text(0, 3, '1.62')
# Text(1, 3, '0.63')
# Text(2, 3, '2.02')
# Text(0, 4, '2.33')
# Text(1, 4, '2.33')
# Text(2, 4, '2.57')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2097', '2.0619', '2.3647']
# ['1.9201', '1.8215', '2.0864']
# ['2.2210', '2.1858', '2.3891']
# ['1.6120', '0.6278', '1.9996']
# ['2.3005', '2.3018', '2.5371']
# Text(0, 0, '2.21')
# Text(1, 0, '2.06')
# Text(2, 0, '2.36')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '2.09')
# Text(0, 2, '2.22')
# Text(1, 2, '2.19')
# Text(2, 2, '2.39')
# Text(0, 3, '1.61')
# Text(1, 3, '0.63')
# Text(2, 3, '2.00')
# Text(0, 4, '2.30')
# Text(1, 4, '2.30')
# Text(2, 4, '2.54')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2056', '2.0590', '2.3620']
# ['1.9174', '1.8215', '2.0850']
# ['2.2158', '2.1809', '2.3853']
# ['1.6080', '0.6240', '1.9988']
# ['2.2846', '2.2849', '2.5266']
# Text(0, 0, '2.21')
# Text(1, 0, '2.06')
# Text(2, 0, '2.36')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '2.08')
# Text(0, 2, '2.22')
# Text(1, 2, '2.18')
# Text(2, 2, '2.39')
# Text(0, 3, '1.61')
# Text(1, 3, '0.62')
# Text(2, 3, '2.00')
# Text(0, 4, '2.28')
# Text(1, 4, '2.28')
# Text(2, 4, '2.53')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2113', '2.0622', '2.3679']
# ['1.9150', '1.8207', '2.0826']
# ['2.2175', '2.1799', '2.3845']
# ['1.5994', '0.6211', '1.9985']
# ['2.2932', '2.3007', '2.5355']
# Text(0, 0, '2.21')
# Text(1, 0, '2.06')
# Text(2, 0, '2.37')
# Text(0, 1, '1.92')
# Text(1, 1, '1.82')
# Text(2, 1, '2.08')
# Text(0, 2, '2.22')
# Text(1, 2, '2.18')
# Text(2, 2, '2.38')
# Text(0, 3, '1.60')
# Text(1, 3, '0.62')
# Text(2, 3, '2.00')
# Text(0, 4, '2.29')
# Text(1, 4, '2.30')
# Text(2, 4, '2.54')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2091', '2.0622', '2.3641']
# ['1.9134', '1.8183', '2.0622']
# ['2.2185', '2.1844', '2.3878']
# ['1.5991', '0.6216', '1.9983']
# ['2.2774', '2.2827', '2.5210']
# Text(0, 0, '2.21')
# Text(1, 0, '2.06')
# Text(2, 0, '2.36')
# Text(0, 1, '1.91')
# Text(1, 1, '1.82')
# Text(2, 1, '2.06')
# Text(0, 2, '2.22')
# Text(1, 2, '2.18')
# Text(2, 2, '2.39')
# Text(0, 3, '1.60')
# Text(1, 3, '0.62')
# Text(2, 3, '2.00')
# Text(0, 4, '2.28')
# Text(1, 4, '2.28')
# Text(2, 4, '2.52')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2129', '2.0622', '2.3741']
# ['1.9142', '1.8183', '2.0832']
# ['2.2201', '2.1852', '2.3923']
# ['1.6077', '0.6313', '2.0077']
# ['2.2822', '2.2822', '2.5269']
# Serial line:
# Text(0, 0, '2.21')
# Text(1, 0, '2.06')
# Text(2, 0, '2.37')
# Text(0, 1, '1.91')
# Text(1, 1, '1.82')
# Text(2, 1, '2.08')
# Text(0, 2, '2.22')
# Text(1, 2, '2.19')
# Text(2, 2, '2.39')
# Text(0, 3, '1.61')
# Text(1, 3, '0.63')
# Text(2, 3, '2.01')
# Text(0, 4, '2.28')
# Text(1, 4, '2.28')
# Text(2, 4, '2.53')
# Serial line:
# Serial line: Matrix updated:
# ['2.1992', '2.0566', '2.3574']
# ['1.9026', '1.8065', '2.0574']
# ['2.2048', '2.1699', '2.3682']
# ['1.5779', '0.6267', '1.9738']
# ['2.2564', '2.2564', '2.4990']
# Text(0, 0, '2.20')
# Text(1, 0, '2.06')
# Text(2, 0, '2.36')
# Text(0, 1, '1.90')
# Text(1, 1, '1.81')
# Text(2, 1, '2.06')
# Text(0, 2, '2.20')
# Text(1, 2, '2.17')
# Text(2, 2, '2.37')
# Text(0, 3, '1.58')
# Text(1, 3, '0.63')
# Text(2, 3, '1.97')
# Text(0, 4, '2.26')
# Text(1, 4, '2.26')
# Text(2, 4, '2.50')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.1981', '2.0552', '2.3459']
# ['1.8957', '1.8032', '2.0472']
# ['2.2038', '2.1675', '2.3590']
# ['1.5730', '0.6243', '1.9604']
# ['2.2306', '2.2322', '2.4748']
# Text(0, 0, '2.20')
# Text(1, 0, '2.06')
# Text(2, 0, '2.35')
# Text(0, 1, '1.90')
# Text(1, 1, '1.80')
# Text(2, 1, '2.05')
# Text(0, 2, '2.20')
# Text(1, 2, '2.17')
# Text(2, 2, '2.36')
# Text(0, 3, '1.57')
# Text(1, 3, '0.62')
# Text(2, 3, '1.96')
# Text(0, 4, '2.23')
# Text(1, 4, '2.23')
# Text(2, 4, '2.47')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.3872', '2.2717', '2.5436']
# ['2.0034', '1.8957', '2.2169']
# ['2.3429', '2.3499', '2.5680']
# ['2.6319', '2.6075', '2.7636']
# ['2.4375', '2.4463', '2.6945']
# Text(0, 0, '2.39')
# Text(1, 0, '2.27')
# Text(2, 0, '2.54')
# Text(0, 1, '2.00')
# Text(1, 1, '1.90')
# Text(2, 1, '2.22')
# Text(0, 2, '2.34')
# Text(1, 2, '2.35')
# Text(2, 2, '2.57')
# Text(0, 3, '2.63')
# Text(1, 3, '2.61')
# Text(2, 3, '2.76')
# Text(0, 4, '2.44')
# Text(1, 4, '2.45')
# Text(2, 4, '2.69')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2878', '2.1277', '2.4076']
# ['1.9566', '1.8495', '2.0622']
# ['2.2384', '2.2148', '2.3843']
# ['2.4495', '2.4885', '2.6293']
# ['2.2467', '2.2897', '2.5084']
# Serial line:
# Text(0, 0, '2.29')
# Text(1, 0, '2.13')
# Text(2, 0, '2.41')
# Text(0, 1, '1.96')
# Text(1, 1, '1.85')
# Text(2, 1, '2.06')
# Text(0, 2, '2.24')
# Text(1, 2, '2.21')
# Text(2, 2, '2.38')
# Text(0, 3, '2.45')
# Text(1, 3, '2.49')
# Text(2, 3, '2.63')
# Text(0, 4, '2.25')
# Text(1, 4, '2.29')
# Text(2, 4, '2.51')
# Serial line:
# Serial line: Matrix updated:
# ['2.2658', '2.1068', '2.3843']
# ['1.9467', '1.8379', '2.0622']
# ['2.2062', '2.1761', '2.3512']
# ['2.4275', '2.4573', '2.6035']
# ['2.2121', '2.2564', '2.4732']
# Text(0, 0, '2.27')
# Text(1, 0, '2.11')
# Text(2, 0, '2.38')
# Text(0, 1, '1.95')
# Text(1, 1, '1.84')
# Text(2, 1, '2.06')
# Text(0, 2, '2.21')
# Text(1, 2, '2.18')
# Text(2, 2, '2.35')
# Text(0, 3, '2.43')
# Text(1, 3, '2.46')
# Text(2, 3, '2.60')
# Text(0, 4, '2.21')
# Text(1, 4, '2.26')
# Text(2, 4, '2.47')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2588', '2.1014', '2.3757']
# ['1.9421', '1.8384', '2.0560']
# ['2.2000', '2.1672', '2.3389']
# ['2.4176', '2.4479', '2.5865']
# ['2.2081', '2.2561', '2.4665']
# Text(0, 0, '2.26')
# Text(1, 0, '2.10')
# Text(2, 0, '2.38')
# Text(0, 1, '1.94')
# Text(1, 1, '1.84')
# Text(2, 1, '2.06')
# Text(0, 2, '2.20')
# Text(1, 2, '2.17')
# Text(2, 2, '2.34')
# Text(0, 3, '2.42')
# Text(1, 3, '2.45')
# Text(2, 3, '2.59')
# Text(0, 4, '2.21')
# Text(1, 4, '2.26')
# Text(2, 4, '2.47')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2594', '2.1020', '2.3716']
# ['1.9397', '1.8349', '2.0506']
# ['2.1938', '2.1602', '2.3289']
# ['2.3947', '2.4219', '2.5591']
# ['2.2086', '2.2545', '2.4595']
# Text(0, 0, '2.26')
# Text(1, 0, '2.10')
# Text(2, 0, '2.37')
# Text(0, 1, '1.94')
# Text(1, 1, '1.83')
# Text(2, 1, '2.05')
# Text(0, 2, '2.19')
# Text(1, 2, '2.16')
# Text(2, 2, '2.33')
# Text(0, 3, '2.39')
# Text(1, 3, '2.42')
# Text(2, 3, '2.56')
# Text(0, 4, '2.21')
# Text(1, 4, '2.25')
# Text(2, 4, '2.46')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2564', '2.0985', '2.3668']
# ['1.9389', '1.8347', '2.0504']
# ['2.1952', '2.1551', '2.3271']
# ['2.3923', '2.4246', '2.5605']
# ['2.2043', '2.2521', '2.4555']
# Serial line:
# Text(0, 0, '2.26')
# Text(1, 0, '2.10')
# Text(2, 0, '2.37')
# Text(0, 1, '1.94')
# Text(1, 1, '1.83')
# Text(2, 1, '2.05')
# Text(0, 2, '2.20')
# Text(1, 2, '2.16')
# Text(2, 2, '2.33')
# Text(0, 3, '2.39')
# Text(1, 3, '2.42')
# Text(2, 3, '2.56')
# Text(0, 4, '2.20')
# Text(1, 4, '2.25')
# Text(2, 4, '2.46')
# Serial line:
# Serial line: Matrix updated:
# ['2.2567', '2.0963', '2.3725']
# ['1.9435', '1.8400', '2.0579']
# ['2.1954', '2.1578', '2.3327']
# ['2.3888', '2.4216', '2.5653']
# ['2.2056', '2.2553', '2.4632']
# Text(0, 0, '2.26')
# Text(1, 0, '2.10')
# Text(2, 0, '2.37')
# Text(0, 1, '1.94')
# Text(1, 1, '1.84')
# Text(2, 1, '2.06')
# Text(0, 2, '2.20')
# Text(1, 2, '2.16')
# Text(2, 2, '2.33')
# Text(0, 3, '2.39')
# Text(1, 3, '2.42')
# Text(2, 3, '2.57')
# Text(0, 4, '2.21')
# Text(1, 4, '2.26')
# Text(2, 4, '2.46')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.3061', '2.1345', '2.4117']
# ['2.0227', '1.8795', '2.1251']
# ['1.7990', '0.6949', '2.0340']
# ['2.3915', '2.3990', '2.5715']
# ['2.1884', '2.2309', '2.4646']
# Text(0, 0, '2.31')
# Text(1, 0, '2.13')
# Text(2, 0, '2.41')
# Text(0, 1, '2.02')
# Text(1, 1, '1.88')
# Text(2, 1, '2.13')
# Text(0, 2, '1.80')
# Text(1, 2, '0.69')
# Text(2, 2, '2.03')
# Text(0, 3, '2.39')
# Text(1, 3, '2.40')
# Text(2, 3, '2.57')
# Text(0, 4, '2.19')
# Text(1, 4, '2.23')
# Text(2, 4, '2.46')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2607', '2.0891', '2.3596']
# ['1.9894', '1.8580', '2.0845']
# ['1.7643', '0.6546', '1.9827']
# ['2.3475', '2.3622', '2.5207']
# ['2.1756', '2.2201', '2.4385']
# Text(0, 0, '2.26')
# Text(1, 0, '2.09')
# Text(2, 0, '2.36')
# Text(0, 1, '1.99')
# Text(1, 1, '1.86')
# Text(2, 1, '2.08')
# Text(0, 2, '1.76')
# Text(1, 2, '0.65')
# Text(2, 2, '1.98')
# Text(0, 3, '2.35')
# Text(1, 3, '2.36')
# Text(2, 3, '2.52')
# Text(0, 4, '2.18')
# Text(1, 4, '2.22')
# Text(2, 4, '2.44')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2650', '2.0864', '2.3835']
# ['1.9983', '1.8610', '2.1022']
# ['1.7681', '0.6463', '2.0157']
# ['2.3698', '2.3856', '2.5581']
# ['2.1713', '2.2175', '2.4549']
# Text(0, 0, '2.27')
# Text(1, 0, '2.09')
# Text(2, 0, '2.38')
# Text(0, 1, '2.00')
# Text(1, 1, '1.86')
# Text(2, 1, '2.10')
# Text(0, 2, '1.77')
# Text(1, 2, '0.65')
# Text(2, 2, '2.02')
# Text(0, 3, '2.37')
# Text(1, 3, '2.39')
# Text(2, 3, '2.56')
# Text(0, 4, '2.17')
# Text(1, 4, '2.22')
# Text(2, 4, '2.45')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2556', '2.0810', '2.3719']
# ['1.9875', '1.8543', '2.0880']
# ['1.7527', '0.6442', '1.9956']
# ['2.3494', '2.3695', '2.5401']
# ['2.1686', '2.2156', '2.4474']
# Serial line:
# Text(0, 0, '2.26')
# Text(1, 0, '2.08')
# Text(2, 0, '2.37')
# Text(0, 1, '1.99')
# Text(1, 1, '1.85')
# Text(2, 1, '2.09')
# Text(0, 2, '1.75')
# Text(1, 2, '0.64')
# Text(2, 2, '2.00')
# Text(0, 3, '2.35')
# Text(1, 3, '2.37')
# Text(2, 3, '2.54')
# Text(0, 4, '2.17')
# Text(1, 4, '2.22')
# Text(2, 4, '2.45')
# Serial line:
# Serial line: Matrix updated:
# ['2.2561', '2.0815', '2.3628']
# ['1.9795', '1.8470', '2.0622']
# ['1.7479', '0.6420', '1.9746']
# ['2.3397', '2.3598', '2.5221']
# ['2.1675', '2.2140', '2.4369']
# Text(0, 0, '2.26')
# Text(1, 0, '2.08')
# Text(2, 0, '2.36')
# Text(0, 1, '1.98')
# Text(1, 1, '1.85')
# Text(2, 1, '2.06')
# Text(0, 2, '1.75')
# Text(1, 2, '0.64')
# Text(2, 2, '1.97')
# Text(0, 3, '2.34')
# Text(1, 3, '2.36')
# Text(2, 3, '2.52')
# Text(0, 4, '2.17')
# Text(1, 4, '2.21')
# Text(2, 4, '2.44')
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2572', '2.0899', '2.3649']
# ['1.9760', '1.8441', '2.0622']
# ['1.7393', '0.6495', '1.9805']
# ['2.3348', '2.3579', '2.5317']
# ['2.1702', '2.2175', '2.4469']
# Text(0, 0, '2.26')
# Text(1, 0, '2.09')
# Text(2, 0, '2.36')
# Text(0, 1, '1.98')
# Text(1, 1, '1.84')
# Text(2, 1, '2.06')
# Text(0, 2, '1.74')
# Text(1, 2, '0.65')
# Text(2, 2, '1.98')
# Text(0, 3, '2.33')
# Text(1, 3, '2.36')
# Text(2, 3, '2.53')
# ...
# ['1.9816', '1.8981', '1.9953']
# ['2.2833', '2.2596', '2.3230']
# ['2.5084', '2.5068', '2.5401']
# ['2.0195', '2.1030', '2.1911']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2204', '2.1541', '2.3085']
# ['1.9830', '1.8978', '1.9956']
# ['2.2849', '2.2591', '2.3228']
# ['2.5159', '2.5132', '2.5444']
# ['2.0249', '2.1063', '2.1954']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2177', '2.1538', '2.3083']
# ['1.9819', '1.8970', '1.9958']
# ['2.2833', '2.2583', '2.3228']
# ['2.5111', '2.5086', '2.5449']
# ['2.0243', '2.1065', '2.1965']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2193', '2.1538', '2.3088']
# ['1.9789', '1.8957', '1.9910']
# ['2.2827', '2.2559', '2.3190']
# ['2.5046', '2.5030', '2.5390']
# ['2.0198', '2.1046', '2.1936']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2191', '2.1535', '2.3083']
# ['1.9789', '1.8957', '1.9918']
# ['2.2838', '2.2575', '2.3206']
# ['2.5043', '2.5049', '2.5390']
# ['2.0235', '2.1054', '2.1936']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2185', '2.1533', '2.3077']
# ['1.9797', '1.8957', '1.9926']
# ['2.2849', '2.2572', '2.3203']
# ['2.5014', '2.4998', '2.5320']
# ['2.0235', '2.1068', '2.1919']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2188', '2.1554', '2.3099']
# ['1.9787', '1.8954', '1.9932']
# ['2.2833', '2.2569', '2.3225']
# ['2.5022', '2.4982', '2.5390']
# ['2.0211', '2.1068', '2.1952']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2199', '2.1557', '2.3109']
# ['1.9776', '1.8943', '1.9902']
# ['2.2835', '2.2567', '2.3217']
# ['2.5052', '2.5033', '2.5401']
# ['2.0243', '2.1068', '2.1987']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2196', '2.1559', '2.3120']
# ['1.9754', '1.8932', '1.9902']
# ['2.2838', '2.2564', '2.3201']
# ['2.5003', '2.4979', '2.5331']
# ['2.0249', '2.1063', '2.2003']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2177', '2.1533', '2.3101']
# ['1.9746', '1.8938', '1.9891']
# ['2.2822', '2.2564', '2.3214']
# ['2.4939', '2.4928', '2.5285']
# ['2.0286', '2.1114', '2.2035']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2185', '2.1533', '2.3080']
# ['1.9776', '1.8938', '1.9894']
# ['2.2857', '2.2564', '2.3214']
# ['2.5049', '2.4992', '2.5299']
# ['2.0273', '2.1105', '2.2027']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2188', '2.1543', '2.3099']
# ['1.9757', '1.8943', '1.9902']
# ['2.2865', '2.2572', '2.3225']
# ['2.4949', '2.4958', '2.5293']
# ['2.0278', '2.1108', '2.2008']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2180', '2.1533', '2.3099']
# ['1.9784', '1.8954', '1.9899']
# ['2.2900', '2.2591', '2.3236']
# ['2.4992', '2.4960', '2.5266']
# ['2.0254', '2.1076', '2.1960']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2175', '2.1541', '2.3099']
# ['1.9795', '1.8943', '1.9891']
# ['2.2913', '2.2591', '2.3279']
# ['2.5022', '2.5009', '2.5320']
# ['2.0316', '2.1135', '2.2035']
# Serial line:
# Serial line: Matrix updated:
# ['2.2150', '2.1530', '2.3085']
# ['1.9803', '1.8940', '1.9883']
# ['2.2943', '2.2621', '2.3244']
# ['2.4974', '2.4931', '2.5283']
# ['2.0305', '2.1140', '2.2021']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2156', '2.1527', '2.3080']
# ['1.9813', '1.8954', '1.9902']
# ['2.2924', '2.2639', '2.3246']
# ['2.5011', '2.4992', '2.5352']
# ['2.0289', '2.1135', '2.2035']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2167', '2.1506', '2.3088']
# ['1.9830', '1.8946', '1.9897']
# ['2.2919', '2.2655', '2.3238']
# ['2.5009', '2.5000', '2.5328']
# ['2.0286', '2.1119', '2.2011']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2164', '2.1506', '2.3083']
# ['1.9813', '1.8954', '1.9889']
# ['2.2886', '2.2618', '2.3238']
# ['2.5027', '2.5017', '2.5355']
# ['2.0243', '2.1068', '2.1952']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2167', '2.1530', '2.3096']
# ['1.9819', '1.8957', '1.9921']
# ['2.2900', '2.2607', '2.3254']
# ['2.5070', '2.5057', '2.5393']
# ['2.0243', '2.1079', '2.1997']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2142', '2.1516', '2.3088']
# ['1.9803', '1.8951', '1.9910']
# ['2.2868', '2.2572', '2.3217']
# ['2.5033', '2.5022', '2.5326']
# ['2.0257', '2.1073', '2.1949']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2134', '2.1500', '2.3066']
# ['1.9803', '1.8954', '1.9897']
# ['2.2895', '2.2586', '2.3214']
# ['2.5062', '2.5046', '2.5371']
# ['2.0243', '2.1041', '2.1930']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2150', '2.1503', '2.3072']
# ['1.9784', '1.8954', '1.9902']
# ['2.2862', '2.2580', '2.3214']
# ['2.5073', '2.5054', '2.5393']
# ['2.0243', '2.1052', '2.1944']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2156', '2.1525', '2.3085']
# ['1.9811', '1.8978', '1.9918']
# ['2.2865', '2.2572', '2.3236']
# ['2.5127', '2.5095', '2.5446']
# ['2.0243', '2.1049', '2.1960']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2177', '2.1533', '2.3096']
# ['1.9805', '1.8967', '1.9907']
# ['2.2865', '2.2599', '2.3214']
# ['2.5070', '2.5065', '2.5417']
# ['2.0235', '2.1033', '2.1922']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2167', '2.1538', '2.3093']
# ['1.9813', '1.8967', '1.9921']
# ['2.2876', '2.2580', '2.3220']
# ['2.5043', '2.5049', '2.5379']
# ['2.0230', '2.1017', '2.1909']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2172', '2.1533', '2.3085']
# ['1.9824', '1.8962', '1.9921']
# ['2.2865', '2.2569', '2.3209']
# ['2.5025', '2.5011', '2.5352']
# ['2.0243', '2.1028', '2.1936']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2177', '2.1538', '2.3083']
# ['1.9813', '1.8967', '1.9924']
# ['2.2868', '2.2594', '2.3246']
# ['2.5025', '2.5006', '2.5339']
# ['2.0243', '2.1028', '2.1930']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2169', '2.1533', '2.3080']
# ['1.9779', '1.8957', '1.9918']
# ['2.2873', '2.2599', '2.3260']
# ['2.5046', '2.5019', '2.5363']
# ['2.0243', '2.1041', '2.1925']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2175', '2.1541', '2.3083']
# ['1.9760', '1.8957', '1.9924']
# ['2.2860', '2.2580', '2.3238']
# ['2.5000', '2.4995', '2.5331']
# ['2.0246', '2.1041', '2.1954']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2177', '2.1543', '2.3099']
# ['1.9779', '1.8951', '1.9924']
# ['2.2841', '2.2583', '2.3220']
# ['2.5049', '2.5035', '2.5395']
# ['2.0224', '2.1033', '2.1957']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2175', '2.1538', '2.3085']
# ['1.9765', '1.8954', '1.9913']
# ['2.2846', '2.2578', '2.3222']
# ['2.5052', '2.4995', '2.5334']
# ['2.0238', '2.1022', '2.1925']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2175', '2.1543', '2.3080']
# ['1.9779', '1.8943', '1.9916']
# ['2.2868', '2.2583', '2.3225']
# ['2.5014', '2.4990', '2.5296']
# ['2.0241', '2.1041', '2.1941']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2164', '2.1535', '2.3077']
# ['1.9768', '1.8938', '1.9902']
# ['2.2865', '2.2580', '2.3241']
# ['2.5014', '2.4979', '2.5288']
# ['2.0214', '2.1020', '2.1914']
# Serial line:
# Serial line: Matrix updated:
# ['2.2175', '2.1538', '2.3080']
# ['1.9733', '1.8927', '1.9886']
# ['2.2843', '2.2575', '2.3220']
# ['2.4990', '2.4974', '2.5301']
# ['2.0208', '2.1017', '2.1879']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2177', '2.1546', '2.3091']
# ['1.9744', '1.8932', '1.9881']
# ['2.2838', '2.2569', '2.3206']
# ['2.5000', '2.4971', '2.5299']
# ['2.0230', '2.1030', '2.1917']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2175', '2.1538', '2.3093']
# ['1.9746', '1.8919', '1.9897']
# ['2.2835', '2.2567', '2.3211']
# ['2.5003', '2.4966', '2.5291']
# ['2.0238', '2.1038', '2.1944']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2167', '2.1538', '2.3083']
# ['1.9736', '1.8914', '1.9894']
# ['2.2830', '2.2567', '2.3206']
# ['2.4968', '2.4955', '2.5320']
# ['2.0241', '2.1063', '2.1979']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2175', '2.1538', '2.3093']
# ['1.9741', '1.8916', '1.9905']
# ['2.2852', '2.2586', '2.3225']
# ['2.4949', '2.4947', '2.5307']
# ['2.0216', '2.1033', '2.1949']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2150', '2.1533', '2.3080']
# ['1.9730', '1.8889', '1.9902']
# ['2.2860', '2.2572', '2.3233']
# ['2.4966', '2.4971', '2.5315']
# ['2.0227', '2.1054', '2.1981']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2148', '2.1527', '2.3077']
# ['1.9733', '1.8876', '1.9899']
# ['2.2822', '2.2548', '2.3209']
# ['2.4952', '2.4939', '2.5304']
# ['2.0219', '2.1025', '2.1965']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2183', '2.1538', '2.3088']
# ['1.9752', '1.8905', '1.9913']
# ['2.2827', '2.2559', '2.3211']
# ['2.5000', '2.4952', '2.5293']
# ['2.0230', '2.1046', '2.1968']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2169', '2.1533', '2.3085']
# ['1.9754', '1.8908', '1.9902']
# ['2.2833', '2.2564', '2.3225']
# ['2.4968', '2.4939', '2.5304']
# ['2.0216', '2.1020', '2.1973']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2172', '2.1533', '2.3085']
# ['1.9744', '1.8911', '1.9905']
# ['2.2849', '2.2567', '2.3222']
# ['2.4979', '2.4974', '2.5368']
# ['2.0216', '2.1017', '2.1970']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2167', '2.1530', '2.3080']
# ['1.9754', '1.8927', '1.9886']
# ['2.2835', '2.2561', '2.3230']
# ['2.5009', '2.4992', '2.5358']
# ['2.0184', '2.1014', '2.1914']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2172', '2.1530', '2.3083']
# ['1.9730', '1.8914', '1.9883']
# ['2.2846', '2.2586', '2.3238']
# ['2.4966', '2.4966', '2.5304']
# ['2.0163', '2.0998', '2.1847']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2167', '2.1538', '2.3080']
# ['1.9754', '1.8932', '1.9891']
# ['2.2849', '2.2572', '2.3230']
# ['2.4966', '2.4941', '2.5304']
# ['2.0219', '2.1014', '2.1917']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2172', '2.1541', '2.3080']
# ['1.9757', '1.8922', '1.9878']
# ['2.2827', '2.2564', '2.3211']
# ['2.4976', '2.4963', '2.5320']
# ['2.0203', '2.1014', '2.1917']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2191', '2.1557', '2.3091']
# ['1.9754', '1.8924', '1.9899']
# ['2.2838', '2.2564', '2.3217']
# ['2.4912', '2.4888', '2.5245']
# ['2.0224', '2.1017', '2.1895']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2193', '2.1554', '2.3099']
# ['1.9752', '1.8908', '1.9870']
# ['2.2830', '2.2551', '2.3211']
# ['2.4901', '2.4906', '2.5266']
# ['2.0238', '2.1030', '2.1938']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2177', '2.1541', '2.3085']
# ['1.9752', '1.8927', '1.9864']
# ['2.2830', '2.2561', '2.3211']
# ['2.4909', '2.4890', '2.5253']
# ['2.0198', '2.1006', '2.1898']
# Serial line:
# Serial line: Matrix updated:
# ['2.2191', '2.1549', '2.3093']
# ['1.9733', '1.8911', '1.9881']
# ['2.2860', '2.2564', '2.3238']
# ['2.4885', '2.4885', '2.5240']
# ['2.0176', '2.1006', '2.1909']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2199', '2.1565', '2.3104']
# ['1.9752', '1.8905', '1.9875']
# ['2.2865', '2.2559', '2.3238']
# ['2.4906', '2.4872', '2.5207']
# ['2.0243', '2.1025', '2.1925']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2188', '2.1543', '2.3093']
# ['1.9776', '1.8922', '1.9856']
# ['2.2854', '2.2564', '2.3246']
# ['2.4888', '2.4882', '2.5229']
# ['2.0243', '2.1030', '2.1927']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2188', '2.1543', '2.3091']
# ['1.9789', '1.8943', '1.9878']
# ['2.2878', '2.2567', '2.3249']
# ['2.4898', '2.4882', '2.5202']
# ['2.0243', '2.1020', '2.1887']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2193', '2.1568', '2.3117']
# ['1.9808', '1.8938', '1.9883']
# ['2.2870', '2.2561', '2.3209']
# ['2.4949', '2.4904', '2.5264']
# ['2.0235', '2.1017', '2.1911']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2201', '2.1568', '2.3112']
# ['1.9792', '1.8948', '1.9894']
# ['2.2854', '2.2559', '2.3222']
# ['2.4979', '2.4947', '2.5296']
# ['2.0243', '2.1030', '2.1965']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2212', '2.1570', '2.3117']
# ['1.9770', '1.8946', '1.9907']
# ['2.2868', '2.2561', '2.3230']
# ['2.5006', '2.4958', '2.5293']
# ['2.0238', '2.1020', '2.1952']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2226', '2.1568', '2.3123']
# ['1.9781', '1.8951', '1.9902']
# ['2.2852', '2.2553', '2.3217']
# ['2.4947', '2.4936', '2.5269']
# ['2.0208', '2.1017', '2.1927']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2220', '2.1570', '2.3104']
# ['1.9808', '1.8951', '1.9937']
# ['2.2881', '2.2556', '2.3220']
# ['2.4936', '2.4888', '2.5242']
# ['2.0241', '2.1017', '2.1944']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2226', '2.1578', '2.3107']
# ['1.9808', '1.8946', '1.9929']
# ['2.2852', '2.2559', '2.3211']
# ['2.4984', '2.5000', '2.5323']
# ['2.0246', '2.1036', '2.1989']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2204', '2.1546', '2.3099']
# ['1.9789', '1.8951', '1.9907']
# ['2.2833', '2.2548', '2.3209']
# ['2.5011', '2.4995', '2.5344']
# ['2.0249', '2.1030', '2.1968']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2215', '2.1570', '2.3147']
# ['1.9811', '1.8951', '1.9926']
# ['2.2870', '2.2561', '2.3217']
# ['2.4990', '2.4971', '2.5323']
# ['2.0284', '2.1071', '2.2005']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2223', '2.1568', '2.3107']
# ['1.9781', '1.8951', '1.9907']
# ['2.2860', '2.2553', '2.3209']
# ['2.4968', '2.4958', '2.5315']
# ['2.0259', '2.1049', '2.1981']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2210', '2.1559', '2.3115']
# ['1.9800', '1.8951', '1.9905']
# ['2.2881', '2.2564', '2.3228']
# ['2.4979', '2.4920', '2.5266']
# ['2.0251', '2.1028', '2.1965']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2210', '2.1557', '2.3123']
# ['1.9781', '1.8951', '1.9924']
# ['2.2868', '2.2564', '2.3236']
# ['2.4992', '2.4966', '2.5312']
# ['2.0259', '2.1063', '2.1989']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2218', '2.1559', '2.3107']
# ['1.9779', '1.8946', '1.9918']
# ['2.2838', '2.2567', '2.3211']
# ['2.4955', '2.4966', '2.5288']
# ['2.0262', '2.1054', '2.1973']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2220', '2.1568', '2.3109']
# ['1.9803', '1.8938', '1.9918']
# ['2.2860', '2.2559', '2.3220']
# ['2.5019', '2.4960', '2.5307']
# ['2.0251', '2.1057', '2.1957']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2210', '2.1554', '2.3120']
# ['1.9789', '1.8943', '1.9897']
# ['2.2835', '2.2548', '2.3195']
# ['2.5014', '2.4984', '2.5307']
# ['2.0241', '2.1033', '2.1936']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2285', '2.1645', '2.3182']
# ['1.9899', '1.8994', '1.9985']
# ['2.2964', '2.2607', '2.3257']
# ['2.5240', '2.5159', '2.5449']
# ['2.0278', '2.1124', '2.2011']
# Serial line:
# Serial line: Matrix updated:
# ['2.2239', '2.1605', '2.3152']
# ['1.9816', '1.8946', '1.9932']
# ['2.2822', '2.2502', '2.3198']
# ['2.4982', '2.4917', '2.5301']
# ['2.0211', '2.1022', '2.1925']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2212', '2.1581', '2.3131']
# ['1.9805', '1.8935', '1.9929']
# ['2.2822', '2.2478', '2.3182']
# ['2.4901', '2.4896', '2.5272']
# ['2.0219', '2.1020', '2.1970']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2145', '2.1533', '2.3080']
# ['1.9773', '1.8884', '1.9889']
# ['2.2787', '2.2441', '2.3128']
# ['2.4890', '2.4885', '2.5256']
# ['2.0227', '2.1017', '2.1954']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2156', '2.1525', '2.3064']
# ['1.9746', '1.8884', '1.9875']
# ['2.2747', '2.2422', '2.3109']
# ['2.4877', '2.4858', '2.5210']
# ['2.0173', '2.0998', '2.1890']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2142', '2.1533', '2.3080']
# ['1.9776', '1.8916', '1.9894']
# ['2.2739', '2.2416', '2.3099']
# ['2.4880', '2.4882', '2.5261']
# ['2.0198', '2.1003', '2.1909']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2140', '2.1522', '2.3077']
# ['1.9768', '1.8905', '1.9891']
# ['2.2749', '2.2408', '2.3083']
# ['2.4888', '2.4906', '2.5288']
# ['2.0181', '2.1020', '2.1909']
# Serial line:
# Serial line:
# Serial line: Matrix updated:
# ['2.2126', '2.1516', '2.3074']
# ['1.9741', '1.8903', '1.9862']
# ['2.2706', '2.2403', '2.3080']
# ['2.4885', '2.4885', '2.5269']
# ['2.0163', '2.0985', '2.1882']
# Serial line:
